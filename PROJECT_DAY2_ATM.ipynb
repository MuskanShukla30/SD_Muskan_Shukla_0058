# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskanShukla30/SD_Muskan_Shukla_0058/blob/main/PROJECT_DAY2_ATM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance=5000
pin=1909
p=int(input("Enter the PIN"))
if p==pin:
  amount=int(input("Enter the amount to be withdrawl"))
  balance=balance-amount
  print("Your balance is",balance)
else:
  print("Invalid PIN")
# Out:
# Enter the PIN1909
# Enter the amount to be withdrawl233
# Your balance is 4767
